# %% [markdown]
# Term Work

# %% [markdown]
# Q1

# %%
"""Question 1"""

#integer variable
my_int = 5
print(my_int)

#float variable
my_float = 5.5
print(my_float)

#string variable
my_string = "Hello"
print(my_string)

#boolean variable
my_bool = True
print(my_bool)

#list variable
my_list = [1,2,3]
print(my_list)

#tuple variable
my_tuple = (1,2,3)
print(my_tuple)

#set variable
my_set = {1,2,3}
print(my_set)

#dictionary variable
my_dict = {"a":1, "b":2, "c":3}
print(my_dict)
# Out:
# 5
# 5.5
# Hello
# True
# [1, 2, 3]
# (1, 2, 3)
# {1, 2, 3}
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# Q2

# %%
"""Q2"""
#Assigning values to variables
a = 10
b = 20

#Assignment operator

print("\nOutput of Assignment operator:\n")
#addition
print("the value of a + b is ", 10+20)
#subtraction
print("the value of a - b is ", 10-20)
#multiplication
print("the value of a * b is ", 10*20)
#division
print("the value of a / b is ", 10/20)
#floor division
print("the value of a // b is", 10//20)
#exponent  
print("the value of a ** b is", 10**20)
#modulus
print("the value of a % b is", 10%20)
#float modulus
print("the value of a % b is", 10.5%20.5)

m=10+20j
n=20+30j
#complex addition
print("\nOutput of complex operator:\n")
print("the value of m + n is", m+n)
#complex subtraction
print("the value of m - n is", m-n)
#complex multiplication
print("the value of m * n is", m*n)
#complex division
print("the value of m / n is", m/n)

"""logical operator"""

print("\nOutput of Logical operator:\n")
#and
print("the value of a and b is", 10 and 20)
#or
print("the value of a or b is", 10 or 20)
#not
print("the value of not a is", not 10)

"""Relational operator"""

print("\nOutput of Relational operator:\n")
#greater than
print("the value of a > b is", 10 > 20)
#less than
print("the value of a < b is", 10 < 20)
#greater than or equal to
print("the value of a >= b is", 10 >= 20)
#less than or equal to
print("the value of a <= b is", 10 <= 20)
#equal to
print("the value of a == b is", 10 == 20)
#not equal to
print("the value of a != b is", 10 != 20)

"""Bitwise operator"""

print("\nOutput of Bitwise operator:\n")
#bitwise and
print("the value of a & b is", 10 & 20)
#bitwise or
print("the value of a | b is", 10 | 20)
#bitwise not
print("the value of ~a is", ~10)
#bitwise xor
print("the value of a ^ b is", 10 ^ 20)
#bitwise right shift
print("the value of a >> b is", 10 >> 20)
#bitwise left shift
print("the value of a << b is", 10 << 20)

#concatenation of string

c='Hello';
d='World';
c=c+d;
print(c)

#list

print("\nOutput of List:\n")
e=[1,2,3];
f=[4,5,6];

e=e+f;
print(e)

#tuple
print("\nOutput of Tuple:\n")
g=(1,2,3);
h=(4,5,6);

g=g+h;
print(g)

#comparison of string
print("\nOutput of Comparison of string:\n")
i='Hello';
j='World';

i=i==j;
print(i)

#complex number
print("\nOutput of Complex number:\n")
k=2+3j;
l=3+4j;

k=k+l;

print(k)
# Out:
# Output of Assignment operator:
#
# the value of a + b is  30
# the value of a - b is  -10
# the value of a * b is  200
# the value of a / b is  0.5
# the value of a // b is 0
# the value of a ** b is 100000000000000000000
# the value of a % b is 10
# the value of a % b is 10.5
#
# Output of complex operator:
#
# the value of m + n is (30+50j)
# the value of m - n is (-10-10j)
# the value of m * n is (-400+700j)
# the value of m / n is (0.6153846153846154+0.0769230769230769j)
#
# Output of Logical operator:
#
# the value of a and b is 20
# the value of a or b is 10
# the value of not a is False
#
# Output of Relational operator:
#
# the value of a > b is False
# the value of a < b is True
# the value of a >= b is False
# the value of a <= b is True
# the value of a == b is False
# the value of a != b is True
#
# Output of Bitwise operator:
#
# the value of a & b is 0
# the value of a | b is 30
# the value of ~a is -11
# the value of a ^ b is 30
# the value of a >> b is 0
# the value of a << b is 10485760
# HelloWorld
#
# Output of List:
#
# [1, 2, 3, 4, 5, 6]
#
# Output of Tuple:
#
# (1, 2, 3, 4, 5, 6)
#
# Output of Comparison of string:
#
# False
#
# Output of Complex number:
#
# (5+7j)
